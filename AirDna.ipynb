# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import *
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as bs
import random 
import undetected_chromedriver as uc
import re
import pandas as pd


path = r'path of file contatined data'
sheet_name = "sheet name contained data of address"
credential = "sheet name contained all login details"




df = pd.read_excel (path, sheet_name=sheet_name)
address = df.iloc[:, 1] # 1st column contained addresses

address =address.values.tolist()
newlist = address

ema = pd.read_excel (path, sheet_name=credential)
email = pd.DataFrame(ema, columns= ['emails'])
password = pd.DataFrame(ema, columns= ['passwords'])
email =email.values.tolist()
password =password.values.tolist()
x = 0
y = 0

# %%
from selenium.webdriver.firefox.options import Options

from selenium.webdriver.support import expected_conditions as EC
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(r'C:\Users\RamishAshraf\Documents\Fiver Work\Amaaz\chromedriver.exe', options=options)

def log_in(address,x,y):
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(r'C:\Users\RamishAshraf\Documents\Fiver Work\Amaaz\chromedriver.exe', options=options)
    driver.get("https://www.airdna.co/vacation-rental-data/app/login")
    time.sleep(1)
    driver.get("https://www.airdna.co/vacation-rental-data/app/login")
    try:
        driver.maximize_window()
    except:
        o = ''
    time.sleep(2)
    try:
        print("log -in button 1")
        log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//body/div/div/header/nav/div/div/a"))).click()
    except:
        try:
            print("log -in button 2")
            log_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//p/button[contains(text(),'Log in')]"))).click()
        except:
            print("not able to click on log i button")
    print('value of x: ',x,' |||| Value of y: ',y)
    time.sleep(1)
    print("email")
    emaill = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[placeholder='Email']")))
    print("password")
    passwordd = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[placeholder='Password']")))
    emaill.clear()
    emaill.send_keys(email[y])
    time.sleep(random.randint(2,4))
    passwordd.clear()
    passwordd.send_keys(password[y])
    try:
        print('sign in button')
        sign_in = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//form/button"))).click()
    except:
        print('Sign_in button is not working')
    time.sleep(random.randint(1,3))
    y+=1
##########################################################################################################################
    newlist = address[x:]
    print('lenght of newlist:  ',len(newlist))
    for i in newlist:
        try:
            driver.get("https://www.airdna.co/vacation-rental-data/app/us/washington/seattle/rentalizer")
            ar = 'na'
            adr = 'na'
            ora = 'na'
            oe = 'na'
            noi = 'na'
            capr = 'na'

            try:
                search = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[@class='address-search__input']/input")))
            except:
                print("Search is not working")
            search.send_keys(i)
            time.sleep(3)
            try:
                search.send_keys(Keys.ENTER)
            except:
                o = 'a'
            try:
                search = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/section/div/div/div/div/div/section[1]/div[1]/div/div[1]/button")))
            except:
                o=''
            print('moving to ar')
            wait = WebDriverWait(driver, 100, poll_frequency=1, ignored_exceptions=[ElementNotVisibleException, ElementNotSelectableException])
            ar =  wait.until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/section/div/div/div/div/div/section[1]/div[1]/div/div[4]/div[1]/p"))).text
            adr =  WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/section/div/div/div/div/div/section[1]/div[1]/div/div[4]/div[2]/p"))).text
            ora =  WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/section/div/div/div/div/div/section[1]/div[1]/div/div[4]/div[3]/p"))).text
            oe =  WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/section/div/div/div/div/div/section[1]/div[2]/section/div[2]/div[1]/div[1]"))).text
            noi =  WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH,"/html/body/div[1]/section/div/div/div/div/div/section[1]/div[2]/section/div[2]/div[1]/div[3]"))).text
            capr =  WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/section/div/div/div/div/div/section[1]/div[2]/section/div[2]/div[1]/div[5]"))).text
            pattern  = ".*" + "Operating Expenses\n"  
            oe = re.sub(pattern, '', oe)
            pattern  = ".*" + "Net Operating Income\n"  
            noi = re.sub(pattern, '', noi)
            pattern  = ".*" + "Cap Rate\n"  
            capr = re.sub(pattern, '', capr)
            rowIndex = df.index[x]
            df.loc[rowIndex, 'Anual Revenue'] = ar
            df.loc[rowIndex, 'Average Daily Rate'] = adr
            df.loc[rowIndex, 'Occupancy Rate'] = ora
            df.loc[rowIndex, 'Operating Expenses'] = oe
            df.loc[rowIndex, 'Net Operating Income'] = noi
            df.loc[rowIndex, 'Cap Rate'] = capr
            print(x)    
            print(i)
            x+=1
            z=0
        except:
            time.sleep(2)
            try:
                limit = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div[2]/div/div/div[1]/div/header/h2"))).text
                if 'maximum number of free' in limit: 
                    time.sleep(random.randint(2,4))
                    print('log_in')
                    import winsound
                    frequency = 1000  # Set Frequency To 2500 Hertz
                    duration = 2000  # Set Duration To 1000 ms == 1 second
                    winsound.Beep(frequency, duration)
                    time.sleep(12)
                    driver.quit()  
                    loop_start(address,x,y)
                    print("loop start")
                    break
            except:
                try:
                    save_file(df)     
                    print("checking search error")
                    if z <2:
                        if z==1:
                            x+=1
                        print('---------------------------------------/\/\/\/\\/\/\/\/\/\/\/\/\/\/\\/\/\-----------------------')
                        z+=1
                        continue
                    elif z>1:
                        print('log_in')
                        import winsound
                        frequency = 1000  # Set Frequency To 2500 Hertz
                        duration = 2000  # Set Duration To 1000 ms == 1 second
                        winsound.Beep(frequency, duration)
                        time.sleep(12)
                        driver.quit()
                        loop_start(address,x,y)
                        print("loop start")
                except:
                    save_file(df) 
                    print('error')
                    frequency = 1000  # Set Frequency To 2500 Hertz
                    duration = 2000  # Set Duration To 1000 ms == 1 second
                    winsound.Beep(frequency, duration)
                    time.sleep(12)
                    break
        save_file(df)





def loop_start(address,x,y):
        log_in(address,x,y)
        import winsound
        frequency = 410  # Set Frequency To 2500 Hertz
        duration = 850  # Set Duration To 1000 ms == 1 second
        winsound.Beep(frequency, duration)
    
    
def save_file(df):
    df = pd.DataFrame.from_dict(df)          #    Creating dataframe from dictionary
    data_2 = "Airdna.xlsx"       ####       Saving data set in Excell
    df.to_excel(data_2)   
 
if __name__ == "__main__":
    log_in(address,x,y)
# Out:
# C:\Users\RamishAshraf\AppData\Local\Temp\ipykernel_14868\1968968767.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\RamishAshraf\Documents\Fiver Work\Amaaz\chromedriver.exe', options=options)
# C:\Users\RamishAshraf\AppData\Local\Temp\ipykernel_14868\1968968767.py:28: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\RamishAshraf\Documents\Fiver Work\Amaaz\chromedriver.exe', options=options)
# log -in button 1
# log -in button 2
# not able to click on log i button
# value of x:  0  |||| Value of y:  0
# email
# password
# sign in button
# lenght of newlist:   792
# moving to ar
# 0
# 8501 Ravenna Avenue NE, Seattle, WA 98115
# moving to ar
# 1
# 9251 8th Avenue SW, Seattle, WA 98106
# moving to ar
# 2
# 5828 16th Avenue S, Seattle, WA 98108
# moving to ar
# 3
# 4410 30th Avenue W, Seattle, WA 98199
# moving to ar
# 4
# ...

# %%
save_file(df)
